# %%
import matplotlib.pyplot as plt
import pandas as pd
import plotly.express as px
import plotly.graph_objects as go
from mpl_toolkits.mplot3d import Axes3D
from sklearn import decomposition
from tqdm.notebook import tqdm as tqdm
from sklearn.decomposition import PCA 
from sklearn.manifold import MDS
import os

# %%
scores_dataframe = pd.read_csv("scores.csv")
scores_dataframe

s = scores_dataframe[['Recall','F-Measure', 'Precision']]

# %%
fig, ax = plt.subplots(figsize=(12, 6))
plt.style.use('seaborn-white')
ax.plot(['Recall','F-Measure', 'Precision'], s.iloc[1], label='JedAI-1', marker='o')  # Plot some data on the axes.
ax.plot(['Recall','F-Measure', 'Precision'], s.iloc[2], label='JedAI-2', marker='*')  # Plot some data on the axes.
ax.plot(['Recall','F-Measure', 'Precision'], s.iloc[3], label='JedAI-3', marker='s')  # Plot some data on the axes.
ax.plot(['Recall','F-Measure', 'Precision'], s.iloc[4], label='JedAI-4', marker='^', c='darkgreen')  # Plot some data on the axes.
ax.plot(['Recall','F-Measure', 'Precision'], s.iloc[5], label='JedAI-5', marker='p')  # Plot some data on the axes.
ax.plot(['Recall','F-Measure', 'Precision'], s.iloc[0], label='WinnER', marker='x', ls='--', markersize=7, lw=2, c='r')  # Plot some data on the axes.

# ax.plot(x, x**2, label='2')  # Plot more data on the axes...
# ax.plot(x, x**3, label='3')  # ... and some more.
ax.set_xlabel('Scores', fontsize=12)  # Add an x-label to the axes.
ax.set_ylabel('Performance (%)', fontsize=12)  # Add a y-label to the axes.
# ax.set_title("Simple Plot")  # Add a title to the axes.
plt.grid(True)
ax.legend(title="Models",bbox_to_anchor=(1.15,1), loc='upper right', fontsize=12, title_fontsize=13);  # Add a legend.
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['left'].set_visible(False)
plt.savefig('scores_comparison.png')
plt.show()
